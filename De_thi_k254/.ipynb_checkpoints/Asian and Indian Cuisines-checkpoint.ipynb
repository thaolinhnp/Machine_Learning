# %% [markdown]
# Cho dữ liệu **asian_india_recipes.csv** chứa công thức (thành phần) nấu ăn của các món ăn một số nước châu Á như Hàn Quốc, Nhật Bản, Trung Quốc, Thái và Ấn Độ.
#
# Yêu cầu: Đọc dữ liệu, chuẩn hóa dữ liệu (nếu cần) và **chọn một thuật toán thích hợp** để thực hiện việc xác định một mẫu có **”cuisine”** là nước nào dựa trên các thông tin được cung cấp.
#
# 1. Tạo X_train, X_test, y_train, y_test từ dữ liệu đã đọc và chuẩn hóa, với tỷ lệ dữ liệu test là 0.3
#
# 2. Áp dụng thuật toán thích hợp để xây dựng model. Dựa trên cơ sở nào để cho rằng thuật toán này thích hợp?
#
# 3. Đánh giá model dựa trên train/test.
#
# 4. Trực quan hóa kết quả (nếu có). Đưa ra một số nhận xét dựa trên kết quả.
#
# 5. Dựa trên kết quả, hãy cho biết nếu trong thành phần của món ăn có “cumin” và “fish” nhưng không có “yogurt” thì món ăn đó thường là món ăn của nước nào?
#
# 6. Dựa trên kết quả, hãy cho biết nếu trong thành phần của món ăn có cumin nhưng không có “fish” và không có “soy_sauce” thì món ăn đó thường là món ăn của nước nào?
#
# 7. In nội dung confusion matrix sau đó trả lời các câu hỏi sau :
#     a. Tỷ lệ % các công thức món ăn của Nhật Bản được dự đoán chính xác ?
#     b. Tỷ lệ % các công thức món ăn của Hàn Quốc bị gán sai nhãn thành Nhật Bản?
#     c. Nước nào có tỷ lệ % các công thức món ăn bị gán nhãn sai nhiều nhất ?

# %% [markdown]
#  **----------------------------------------------------  DATA OVERVIEW  ----------------------------------------------------------**

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
data = pd.read_csv('du lieu cung cap/asian_indian_recipes.csv', index_col = 0)

# %%
print('Number of rows:',data.shape[0])
print('Number of columns:',data.shape[1])
# Out:
# Number of rows: 2448
# Number of columns: 384

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2448 entries, 65 to 57690
# Columns: 384 entries, cuisine to zucchini
# dtypes: int64(383), object(1)
# memory usage: 7.2+ MB

# %%
data.head()
# Out:
#    cuisine  almond  angelica  anise  anise_seed  apple  apple_brandy  apricot  \
# 65  indian       0         0      0           0      0             0        0
# 66  indian       1         0      0           0      0             0        0
# 67  indian       0         0      0           0      0             0        0
# 68  indian       0         0      0           0      0             0        0
# 69  indian       0         0      0           0      0             0        0
#
#     armagnac  artemisia  ...  whiskey  white_bread  white_wine  \
# 65         0          0  ...        0            0           0
# 66         0          0  ...        0            0           0
# 67         0          0  ...        0            0           0
# 68         0          0  ...        0            0           0
# 69         0          0  ...        0            0           0
#
#     whole_grain_wheat_flour  wine  wood  yam  yeast  yogurt  zucchini
# 65                        0     0     0    0      0       0         0
# 66                        0     0     0    0      0       0         0
# 67                        0     0     0    0      0       0         0
# 68                        0     0     0    0      0       0         0
# 69                        0     0     0    0      0       1         0
#
# [5 rows x 384 columns]

# %%
descrip = data.describe(include='all').transpose()
pd.options.display.max_rows = 1000
display(descrip)
pd.options.display.max_rows = 15
# Out:
#                         count unique     top freq         mean        std  \
# cuisine                  2448      5  korean  799          NaN        NaN
# almond                   2448    NaN     NaN  NaN    0.0183824   0.134357
# angelica                 2448    NaN     NaN  NaN            0          0
# yeast                      0    0    0    0    1
# yogurt                     0    0    0    0    1
# zucchini                   0    0    0    0    1

# %% [markdown]
# **1. Tạo X_train, X_test, y_train, y_test từ dữ liệu đã đọc và chuẩn hóa, với tỷ lệ dữ liệu test là 0.3**

# %% [markdown]
# **1.1. Giữ nguyên bộ inputs và outputs**

# %%
inputs = data.iloc[:,1:]
inputs.shape
# Out:
# (2448, 383)

# %%
inputs.head()
# Out:
#     almond  angelica  anise  anise_seed  apple  apple_brandy  apricot  \
# 65       0         0      0           0      0             0        0
# 66       1         0      0           0      0             0        0
# 67       0         0      0           0      0             0        0
# 68       0         0      0           0      0             0        0
# 69       0         0      0           0      0             0        0
#
#     armagnac  artemisia  artichoke  ...  whiskey  white_bread  white_wine  \
# 65         0          0          0  ...        0            0           0
# 66         0          0          0  ...        0            0           0
# 67         0          0          0  ...        0            0           0
# 68         0          0          0  ...        0            0           0
# 69         0          0          0  ...        0            0           0
#
#     whole_grain_wheat_flour  wine  wood  yam  yeast  yogurt  zucchini
# 65                        0     0     0    0      0       0         0
# 66                        0     0     0    0      0       0         0
# 67                        0     0     0    0      0       0         0
# 68                        0     0     0    0      0       0         0
# 69                        0     0     0    0      0       1         0
#
# [5 rows x 383 columns]

# %%
outputs = data[['cuisine']]
outputs['cuisine'].unique()
# Out:
# array(['indian', 'thai', 'chinese', 'japanese', 'korean'], dtype=object)

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(inputs, outputs, test_size=0.30,random_state = 42)

# %% [markdown]
# **1.2. Xử lý Inputs:** Có nhiều columns chỉ có giá trị 0 => remove

# %%
cols_lst = data.columns.to_list()
cols_lst.remove('cuisine')

# %%
from tqdm import tqdm_notebook as tqdm

cols_del = list()
for name, column in tqdm(data[cols_lst].iteritems(), total=len(cols_lst)):
    if (column.count() == 0) or (column.max() == column.min()):
        cols_del.append(name)
        cols_lst.remove(name)
        
if len(cols_del) > 0:
    print(len(cols_del), 'columns will not be further used as they have only 1 unique level.')
else:
    print('All predictors have more than 1 unique level.')
# Out:
# HBox(children=(IntProgress(value=0, max=383), HTML(value='')))
# 99 columns will not be further used as they have only 1 unique level.

# %%
inputs_non_zero = data[cols_lst]
inputs_non_zero.shape
# Out:
# (2448, 284)

# %%
inputs_non_zero.head()
# Out:
#     almond  anise  anise_seed  apple  apricot  artemisia  asparagus  avocado  \
# 65       0      0           0      0        0          0          0        0
# 66       1      0           0      0        0          0          0        0
# 67       0      0           0      0        0          0          0        0
# 68       0      0           0      0        0          0          0        0
# 69       0      0           0      0        0          0          0        0
#
#     bacon  banana  ...  wheat  wheat_bread  white_bread  white_wine  \
# 65      0       0  ...      0            0            0           0
# 66      0       0  ...      0            0            0           0
# 67      0       0  ...      0            0            0           0
# 68      0       0  ...      1            0            0           0
# 69      0       0  ...      0            0            0           0
#
#     whole_grain_wheat_flour  wine  yam  yeast  yogurt  zucchini
# 65                        0     0    0      0       0         0
# 66                        0     0    0      0       0         0
# 67                        0     0    0      0       0         0
# 68                        0     0    0      0       0         0
# 69                        0     0    0      0       1         0
#
# [5 rows x 284 columns]

# %% [markdown]
# **1.3. Xử lý Output:** Dành cho các model yêu cầu output là int

# %%
from sklearn.preprocessing import LabelEncoder
lb_cuisine = LabelEncoder()
cuisine_df = data[['cuisine']]
cuisine_df["cuisine_code"] = lb_cuisine.fit_transform(cuisine_df["cuisine"])

# check outputs coding
cuisine_df.drop_duplicates()
# Out:
#         cuisine  cuisine_code
# 65       indian             1
# 2333       thai             4
# 10734   chinese             0
# 11301  japanese             2
# 15025    korean             3

# %%
outputs_int = cuisine_df[['cuisine_code']]
outputs_int['cuisine_code'].unique()
# Out:
# array([1, 4, 0, 2, 3], dtype=int64)

# %% [markdown]
# **2. Áp dụng thuật toán thích hợp để xây dựng model. Dựa trên cơ sở nào để cho rằng thuật toán này thích hợp?**
#
# **3. Đánh giá model dựa trên train/test**
#
# **4. Trực quan hóa kết quả (nếu có). Đưa ra một số nhận xét dựa trên kết quả**

# %% [markdown]
# Đây là bài toán Classification thuộc nhóm Supervised Learning. Output là multi-class và dữ liệu input nhiều chiều.
# Một số model có thể dùng cho dạng bài toán này:
#     1. KNN - Classification
#     2. Decision Tree
#     3. Random Forest

# %% [markdown]
#  **---------------------------------------------------- 1. KNN CLASSISFICATION  ----------------------------------------------------------**

# %% [markdown]
# **Tìm best K**

# %%
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
list_k = []
list_acc = []
for K_value in range(1,int(y_train.shape[0]**0.5)):        
    list_k.append(K_value)
    neigh = KNeighborsClassifier(n_neighbors = K_value)
    neigh.fit(X_train, y_train) 
    y_pred = neigh.predict(X_test)
    acc = accuracy_score(y_test,y_pred)*100 
    list_acc.append(acc)
    print("Accuracy is ", accuracy_score(y_test,y_pred)*100,"% for K-Value:",K_value)
# Out:
# Accuracy is  69.25170068027211 % for K-Value: 1
# Accuracy is  66.25850340136054 % for K-Value: 2
# Accuracy is  71.156462585034 % for K-Value: 3
# Accuracy is  70.06802721088435 % for K-Value: 4
# Accuracy is  71.29251700680273 % for K-Value: 5
# Accuracy is  69.38775510204081 % for K-Value: 6
# Accuracy is  70.34013605442176 % for K-Value: 7
# Accuracy is  69.79591836734694 % for K-Value: 8
# Accuracy is  70.20408163265306 % for K-Value: 9
# Accuracy is  70.61224489795919 % for K-Value: 10
# Accuracy is  70.8843537414966 % for K-Value: 11
# Accuracy is  71.42857142857143 % for K-Value: 12
# Accuracy is  71.56462585034014 % for K-Value: 13
# Accuracy is  71.97278911564626 % for K-Value: 14
# Accuracy is  71.97278911564626 % for K-Value: 15
# Accuracy is  71.83673469387755 % for K-Value: 16
# Accuracy is  71.42857142857143 % for K-Value: 17
# Accuracy is  70.8843537414966 % for K-Value: 18
# Accuracy is  72.51700680272108 % for K-Value: 19
# Accuracy is  71.56462585034014 % for K-Value: 20
# Accuracy is  71.56462585034014 % for K-Value: 21
# Accuracy is  70.61224489795919 % for K-Value: 22
# Accuracy is  70.61224489795919 % for K-Value: 23
# Accuracy is  70.20408163265306 % for K-Value: 24
# Accuracy is  69.79591836734694 % for K-Value: 25
# Accuracy is  69.65986394557822 % for K-Value: 26
# Accuracy is  69.65986394557822 % for K-Value: 27
# Accuracy is  69.79591836734694 % for K-Value: 28
# Accuracy is  69.65986394557822 % for K-Value: 29
# Accuracy is  69.79591836734694 % for K-Value: 30
# Accuracy is  68.70748299319727 % for K-Value: 31
# Accuracy is  68.43537414965986 % for K-Value: 32
# Accuracy is  69.38775510204081 % for K-Value: 33
# Accuracy is  68.84353741496598 % for K-Value: 34
# Accuracy is  68.57142857142857 % for K-Value: 35
# Accuracy is  67.4829931972789 % for K-Value: 36
# Accuracy is  67.4829931972789 % for K-Value: 37
# Accuracy is  66.80272108843538 % for K-Value: 38
# Accuracy is  66.25850340136054 % for K-Value: 39
# Accuracy is  65.3061224489796 % for K-Value: 40

# %%
import matplotlib.pyplot as plt
plt.plot(list_k, list_acc)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Test Accuracy')
plt.show()

# %%
vi_tri = list_acc.index(max(list_acc))
k = list_k[vi_tri]
print("The optimal number of neighbors is", k,"with", list_acc[vi_tri])
# Out:
# The optimal number of neighbors is 19 with 72.51700680272108

# %%
# select k => ap dung model
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=19, p=2,
#            weights='uniform')

# %%
y_pred = knn.predict(X_test)

# %%
# Kiểm tra độ chính xác
print("The Train prediction accuracy is: ", 
      knn.score(X_train,y_train)*100,"%")
print("The Test prediction accuracy is: ", 
      knn.score(X_test,y_test)*100,"%")
# Out:
# The Train prediction accuracy is:  74.83946293053123 %
# The Test prediction accuracy is:  72.51700680272108 %

# %% [markdown]
# **Đánh giá model => Dùng confuse matrix**

# %%
y_pred = knn.predict(X_test)

# %%
df = pd.DataFrame({'Actual': pd.DataFrame(y_test['cuisine'].to_list())[0].values, 
                   'Prediction': pd.DataFrame(y_pred)[0].values})  
df.head()
# Out:
#    Actual Prediction
# 0  korean     korean
# 1  korean     korean
# 2  korean     korean
# 3  korean     korean
# 4    thai       thai

# %%
from sklearn.metrics import confusion_matrix, classification_report
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 77,   7,   9,  52,   0],
#        [  3, 164,   0,   9,   1],
#        [  3,   7,  48,  30,   0],
#        [  3,   7,   6, 213,   0],
#        [ 11,  28,   3,  23,  31]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      chinese       0.79      0.53      0.64       145
#       indian       0.77      0.93      0.84       177
#     japanese       0.73      0.55      0.62        88
#       korean       0.65      0.93      0.77       229
#         thai       0.97      0.32      0.48        96
#
#    micro avg       0.73      0.73      0.73       735
#    macro avg       0.78      0.65      0.67       735
# weighted avg       0.76      0.73      0.70       735

# %% [markdown]
# **=> Quan sát kết quả và đánh giá: Mô hình có độ chính xác tầm 72%, không bị overfitting, class dự đoán tương đối**

# %% [markdown]
# **Try Feature Selection:** Thử chọn lọc fearture để xem có thể giảm độ nhiễu, tăng score cho Model được hay không?

# %%
#get correlations of each features in dataset
data_sub = inputs.iloc[:,1:]
corrmat = data_sub.corr()
top_corr_features = corrmat.index

# %%
data_sub.corr()
# Out:
#                          angelica     anise  anise_seed     apple  \
# angelica                      NaN       NaN         NaN       NaN
# anise                         NaN  1.000000   -0.001083 -0.002399
# anise_seed                    NaN -0.001083    1.000000 -0.006355
# apple                         NaN -0.002399   -0.006355  1.000000
# apple_brandy                  NaN       NaN         NaN       NaN
# apricot                       NaN -0.001477   -0.003913  0.135408
# armagnac                      NaN       NaN         NaN       NaN
# ...                           ...       ...         ...       ...
# whole_grain_wheat_flour       NaN -0.001295   -0.003430  0.047124
# wine                          NaN -0.005452   -0.014443 -0.032009
# wood                          NaN       NaN         NaN       NaN
# yam                           NaN -0.000818   -0.002166 -0.004801
# yeast                         NaN -0.002538   -0.006724 -0.014902
# yogurt                        NaN -0.005072   -0.013437  0.014581
# zucchini                      NaN -0.001880   -0.004981  0.026810
#
#                          apple_brandy   apricot  armagnac  artemisia  \
# angelica                          NaN       NaN       NaN        NaN
# anise                             NaN -0.001477       NaN  -0.001002
# anise_seed                        NaN -0.003913       NaN  -0.002654
# apple                             NaN  0.135408       NaN  -0.005883
# apple_brandy                      NaN       NaN       NaN        NaN
# apricot                           NaN  1.000000       NaN  -0.003622
# armagnac                          NaN       NaN       NaN        NaN
# ...                               ...       ...       ...        ...
# whole_grain_wheat_flour           NaN -0.004680       NaN  -0.003175
# wine                              NaN  0.002648       NaN  -0.013369
# wood                              NaN       NaN       NaN        NaN
# yam                               NaN -0.002956       NaN  -0.002005
# yeast                             NaN  0.036291       NaN  -0.006224
# yogurt                            NaN -0.018334       NaN  -0.012438
# zucchini                          NaN -0.006797       NaN  -0.004611
#
#                          artichoke  asparagus  ...  whiskey  white_bread  \
# angelica                       NaN        NaN  ...      NaN          NaN
# anise                          NaN  -0.001690  ...      NaN    -0.000578
# anise_seed                     NaN  -0.004478  ...      NaN    -0.001531
# apple                          NaN   0.032108  ...      NaN    -0.003394
# apple_brandy                   NaN        NaN  ...      NaN          NaN
# apricot                        NaN  -0.006110  ...      NaN    -0.002089
# armagnac                       NaN        NaN  ...      NaN          NaN
# ...                            ...        ...  ...      ...          ...
# whole_grain_wheat_flour        NaN  -0.005356  ...      NaN    -0.001831
# wine                           NaN   0.016576  ...      NaN    -0.007712
# wood                           NaN        NaN  ...      NaN          NaN
# yam                            NaN  -0.003383  ...      NaN    -0.001157
# yeast                          NaN  -0.010501  ...      NaN    -0.003591
# yogurt                         NaN  -0.020983  ...      NaN    -0.007175
# zucchini                       NaN   0.045561  ...      NaN    -0.002660
#
#                          white_wine  whole_grain_wheat_flour      wine  wood  \
# angelica                        NaN                      NaN       NaN   NaN
# anise                     -0.002949                -0.001295 -0.005452   NaN
# anise_seed                -0.007811                -0.003430 -0.014443   NaN
# apple                      0.031567                 0.047124 -0.032009   NaN
# apple_brandy                    NaN                      NaN       NaN   NaN
# apricot                   -0.010658                -0.004680  0.002648   NaN
# armagnac                        NaN                      NaN       NaN   NaN
# ...                             ...                      ...       ...   ...
# whole_grain_wheat_flour   -0.009342                 1.000000 -0.017273   NaN
# wine                       0.006162                -0.017273  1.000000   NaN
# wood                            NaN                      NaN       NaN   NaN
# yam                       -0.005901                -0.002591 -0.010911   NaN
# yeast                     -0.018316                -0.008042 -0.033867   NaN
# yogurt                    -0.012368                 0.065322 -0.067676   NaN
# zucchini                  -0.013568                -0.005957 -0.025088   NaN
#
#                               yam     yeast    yogurt  zucchini
# angelica                      NaN       NaN       NaN       NaN
# anise                   -0.000818 -0.002538 -0.005072 -0.001880
# anise_seed              -0.002166 -0.006724 -0.013437 -0.004981
# apple                   -0.004801 -0.014902  0.014581  0.026810
# apple_brandy                  NaN       NaN       NaN       NaN
# apricot                 -0.002956  0.036291 -0.018334 -0.006797
# armagnac                      NaN       NaN       NaN       NaN
# ...                           ...       ...       ...       ...
# whole_grain_wheat_flour -0.002591 -0.008042  0.065322 -0.005957
# wine                    -0.010911 -0.033867 -0.067676 -0.025088
# wood                          NaN       NaN       NaN       NaN
# yam                      1.000000 -0.005080 -0.010151 -0.003763
# yeast                   -0.005080  1.000000  0.038484 -0.011680
# yogurt                  -0.010151  0.038484  1.000000  0.014188
# zucchini                -0.003763 -0.011680  0.014188  1.000000
#
# [382 rows x 382 columns]

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),cmap="RdYlGn") # annot=True: nếu muốn in cả giá trị

# %% [markdown]
# => Quá nhiều inputs, không nhìn được sự tương quan giữa các biến

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
#apply SelectKBest class to extract all best features
bestfeatures = SelectKBest(score_func=chi2, k='all')
fit = bestfeatures.fit(inputs,outputs)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(inputs.columns)

# %%
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
pd.options.display.max_rows = 1000
display(featureScores.sort_values(by='Score',ascending=False))
pd.options.display.max_rows = 15
# Out:
#                        Specs       Score
# 112                    cumin  835.566663
# 359                 turmeric  696.794092
# 102                coriander  623.552595
# 180               lemongrass  549.467849
# 95                   coconut  445.807853
# 293      roasted_sesame_seed  438.111678
# 381                   yogurt  416.588793
# 187               lime_juice  404.040015
# 88                  cilantro  376.455635
# 126                fenugreek  376.020556
# 337                   starch  373.928672
# 330                soy_sauce  360.079267
# 129                     fish  331.035466
# 316               sesame_oil  319.951717
# 186                     lime  259.732056
# 59                  cardamom  259.524551
# 18                     basil  256.711448
# 377                     wine  249.868102
# 311                 scallion  244.448695
# 314                  seaweed  241.362109
# 253                   pepper  235.628198
# 354                   tomato  235.457291
# 263                     pork  231.810621
# 368                   wasabi  224.397606
# 331                  soybean  210.678191
# 305                     sake  204.739445
# 363                vegetable  199.896558
# 51                    butter  193.431986
# 89                  cinnamon  187.545916
# 133                  galanga  185.230048
# 318                  shallot  182.746360
# 211                     mint  159.051552
# 81             chicken_broth  156.694249
# 16                    barley  153.894009
# 274                   radish  153.505017
# 352              thai_pepper  152.979029
# 165              katsuobushi  149.966546
# 247            peanut_butter  147.477808
# 80                   chicken  145.346584
# 229                olive_oil  142.277590
# 68                   cayenne  142.067068
# 22                      beef  140.938340
# 230                    onion  135.020800
# 178              lemon_juice  134.039380
# 290           roasted_peanut  132.688195
# 248               peanut_oil  118.536009
# 365                  vinegar  110.609270
# 321                   sherry  107.084317
# 315                     seed  106.786036
# 237                   oyster  102.787722
# 243            passion_fruit    3.093645
# 262                  porcini    3.093645
# 268              potato_chip    3.093645
# 38                blackberry    3.093645
# 75            cheddar_cheese    2.816054
# 30             bitter_orange    2.816054
# 310                   savory    2.816054
# 299                      rum    2.816054
# 199                     malt    2.816054
# 192                  lobster    2.760702
# 26                      beet    2.599842
# 99                    cognac    2.301146
# 104               corn_flake    2.301146
# 286             roasted_beef    2.111800
# 309               sauerkraut    2.063830
# 279                red_algae    2.063830
# 278                 raw_beef    2.063830
# 212        mozzarella_cheese    2.063830
# 24                beef_liver    2.063830
# 228                    olive    1.819516
# 344             sweet_potato    1.722388
# 380                    yeast    1.095769
# 164                     kale    1.071603
# 1                   angelica         NaN
# 5               apple_brandy         NaN
# 7                   armagnac         NaN
# 9                  artichoke         NaN
# 13              baked_potato         NaN
# 14                      balm         NaN
# 17             bartlett_pear         NaN
# 28                  bergamot         NaN
# 32             black_currant         NaN
# 35           black_raspberry         NaN
# 39         blackberry_brandy         NaN
# 40               blue_cheese         NaN
# 43           bourbon_whiskey         NaN
# 54   cabernet_sauvignon_wine         NaN
# 55                     cacao         NaN
# 56          camembert_cheese         NaN
# 60                 carnation         NaN
# 61                     carob         NaN
# 64                   cassava         NaN
# 71                    cereal         NaN
# 72                 chamomile         NaN
# 78             cherry_brandy         NaN
# 82             chicken_liver         NaN
# 93                     clove         NaN
# 100            concord_grape         NaN
# 101                condiment         NaN
# 105                corn_grit         NaN
# 106           cottage_cheese         NaN
# 113               cured_pork         NaN
# 117                   durian         NaN
# 121               elderberry         NaN
# 122          emmental_cheese         NaN
# 130                   flower         NaN
# 137                 geranium         NaN
# 142             grape_brandy         NaN
# 148                    guava         NaN
# 151                 hazelnut         NaN
# 152                  herring         NaN
# 155                      hop         NaN
# 157              huckleberry         NaN
# 158             jamaican_rum         NaN
# 161              jasmine_tea         NaN
# 162            juniper_berry         NaN
# 163              kaffir_lime         NaN
# 173                   laurel         NaN
# 174                 lavender         NaN
# 175                     leaf         NaN
# 184         lilac_flower_oil         NaN
# 189              lingonberry         NaN
# 193              long_pepper         NaN
# 194                   lovage         NaN
# 205                     mate         NaN
# 214           munster_cheese         NaN
# 215             muscat_grape         NaN
# 219                   mutton         NaN
# 220                nectarine         NaN
# 224                      oat         NaN
# 232            orange_flower         NaN
# 236                     ouzo         NaN
# 250              pear_brandy         NaN
# 252              pelargonium         NaN
# 255           peppermint_oil         NaN
# 256                  pimenta         NaN
# 257                  pimento         NaN
# 261                  popcorn         NaN
# 264               pork_liver         NaN
# 266                port_wine         NaN
# 270             prickly_pear         NaN
# 273                   quince         NaN
# 276                 rapeseed         NaN
# 281          red_kidney_bean         NaN
# 283                  rhubarb         NaN
# 285           roasted_almond         NaN
# 287         roasted_hazelnut         NaN
# 288             roasted_meat         NaN
# 289              roasted_nut         NaN
# 291            roasted_pecan         NaN
# 294            romano_cheese         NaN
# 296         roquefort_cheese         NaN
# 300                 rutabaga         NaN
# 301                rye_bread         NaN
# 302                rye_flour         NaN
# 308                sassafras         NaN
# 319             sheep_cheese         NaN
# 325              smoked_fish         NaN
# 327           smoked_sausage         NaN
# 329                sour_milk         NaN
# 332              soybean_oil         NaN
# 333                spearmint         NaN
# 339           strawberry_jam         NaN
# 340         strawberry_juice         NaN
# 341          sturgeon_caviar         NaN
# 342                    sumac         NaN
# 345             swiss_cheese         NaN
# 351                  tequila         NaN
# 356                  truffle         NaN
# 366                   violet         NaN
# 373                  whiskey         NaN
# 378                     wood         NaN

# %%
#visualization feature selection
nlargest = 100 # xem thử 100 biến có score lớn nhất

plt.figure(figsize = (20,5))
plt.bar(featureScores.nlargest(nlargest,'Score').Specs.values, featureScores.nlargest(nlargest,'Score').Score.values)
plt.show()

# %% [markdown]
# **1. Thử chọn những feature có score > 300 (còn 14 biến inputs)**
#     1.1. The Train prediction accuracy is:  64.91535318155283 %
#     1.2. The Test prediction accuracy is:  64.08163265306122 %
#
# **=> Độ chính xác của model bị giảm**

# %% [markdown]
# **2. Thử chọn những feature có score > 200 (còn 26 biến inputs)**
# 2.1. The Train prediction accuracy is:  72.50437828371278 %
# 2.2. The Test prediction accuracy is:  69.52380952380952 %
#
# **=> Độ chính xác của model bị giảm, tốc độ xử lý nhanh hơn **

# %%
best_feature = featureScores[featureScores['Score'] > 200]['Specs'].values
best_feature
# Out:
# array(['basil', 'cardamom', 'cilantro', 'coconut', 'coriander', 'cumin',
#        'fenugreek', 'fish', 'lemongrass', 'lime', 'lime_juice', 'pepper',
#        'pork', 'roasted_sesame_seed', 'sake', 'scallion', 'seaweed',
#        'sesame_oil', 'soy_sauce', 'soybean', 'starch', 'tomato',
#        'turmeric', 'wasabi', 'wine', 'yogurt'], dtype=object)

# %%
inputs_best = data[best_feature]
inputs_best.head()
# Out:
#     basil  cardamom  cilantro  coconut  coriander  cumin  fenugreek  fish  \
# 65      0         0         0        1          1      1          1     1
# 66      0         1         0        0          0      0          0     0
# 67      0         1         0        0          0      0          0     0
# 68      0         0         0        1          0      0          1     0
# 69      0         1         0        0          0      1          0     0
#
#     lemongrass  lime  ...  seaweed  sesame_oil  soy_sauce  soybean  starch  \
# 65           0     0  ...        0           0          0        0       0
# 66           0     0  ...        0           0          0        0       0
# 67           0     0  ...        0           0          0        0       0
# 68           0     0  ...        0           0          0        0       0
# 69           0     0  ...        0           0          0        0       0
#
#     tomato  turmeric  wasabi  wine  yogurt
# 65       1         1       0     0       0
# 66       0         0       0     0       0
# 67       0         0       0     0       0
# 68       1         1       0     0       0
# 69       0         0       0     0       1
#
# [5 rows x 26 columns]

# %%
from sklearn.model_selection import train_test_split  
X_train_best, X_test_best, y_train_best, y_test_best = train_test_split(inputs_best, outputs, test_size=0.30)

# %%
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
list_k = []
list_acc = []
for K_value in range(1,int(y_train_best.shape[0]**0.5)):        
    list_k.append(K_value)
    neigh = KNeighborsClassifier(n_neighbors = K_value)
    neigh.fit(X_train_best, y_train_best) 
    y_pred_best = neigh.predict(X_test_best)
    acc = accuracy_score(y_test_best,y_pred_best)*100 
    list_acc.append(acc)
    print("Accuracy is ", accuracy_score(y_test_best,y_pred_best)*100,"% for K-Value:",K_value)
# Out:
# Accuracy is  63.26530612244898 % for K-Value: 1
# Accuracy is  59.455782312925166 % for K-Value: 2
# Accuracy is  63.129251700680264 % for K-Value: 3
# Accuracy is  66.80272108843538 % for K-Value: 4
# Accuracy is  65.3061224489796 % for K-Value: 5
# Accuracy is  68.57142857142857 % for K-Value: 6
# Accuracy is  67.75510204081633 % for K-Value: 7
# Accuracy is  67.4829931972789 % for K-Value: 8
# Accuracy is  67.89115646258503 % for K-Value: 9
# Accuracy is  68.29931972789116 % for K-Value: 10
# Accuracy is  67.89115646258503 % for K-Value: 11
# Accuracy is  69.25170068027211 % for K-Value: 12
# Accuracy is  68.02721088435374 % for K-Value: 13
# Accuracy is  68.9795918367347 % for K-Value: 14
# Accuracy is  66.66666666666666 % for K-Value: 15
# Accuracy is  68.70748299319727 % for K-Value: 16
# Accuracy is  68.9795918367347 % for K-Value: 17
# Accuracy is  69.52380952380952 % for K-Value: 18
# Accuracy is  68.57142857142857 % for K-Value: 19
# Accuracy is  68.57142857142857 % for K-Value: 20
# Accuracy is  68.57142857142857 % for K-Value: 21
# Accuracy is  68.43537414965986 % for K-Value: 22
# Accuracy is  68.02721088435374 % for K-Value: 23
# Accuracy is  68.16326530612244 % for K-Value: 24
# Accuracy is  67.61904761904762 % for K-Value: 25
# Accuracy is  67.61904761904762 % for K-Value: 26
# Accuracy is  67.89115646258503 % for K-Value: 27
# Accuracy is  68.02721088435374 % for K-Value: 28
# Accuracy is  66.53061224489795 % for K-Value: 29
# Accuracy is  66.80272108843538 % for K-Value: 30
# Accuracy is  66.93877551020408 % for K-Value: 31
# Accuracy is  66.12244897959184 % for K-Value: 32
# Accuracy is  66.25850340136054 % for K-Value: 33
# Accuracy is  66.12244897959184 % for K-Value: 34
# Accuracy is  65.85034013605441 % for K-Value: 35
# Accuracy is  66.12244897959184 % for K-Value: 36
# Accuracy is  64.62585034013605 % for K-Value: 37
# Accuracy is  65.578231292517 % for K-Value: 38
# Accuracy is  66.25850340136054 % for K-Value: 39
# Accuracy is  65.3061224489796 % for K-Value: 40

# %%
import matplotlib.pyplot as plt
plt.plot(list_k, list_acc)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Test Accuracy')
plt.show()

# %%
vi_tri = list_acc.index(max(list_acc))
k = list_k[vi_tri]
print("The optimal number of neighbors is", k,"with", list_acc[vi_tri])
# Out:
# The optimal number of neighbors is 18 with 69.52380952380952

# %%
# select k => ap dung model
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train_best, y_train_best)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=18, p=2,
#            weights='uniform')

# %%
y_pred_best = knn.predict(X_test_best)

# %%
# Kiểm tra độ chính xác
print("The Train prediction accuracy is: ", 
      knn.score(X_train_best,y_train_best)*100,"%")
print("The Test prediction accuracy is: ", 
      knn.score(X_test_best,y_test_best)*100,"%")
# Out:
# The Train prediction accuracy is:  72.50437828371278 %
# The Test prediction accuracy is:  69.52380952380952 %

# %% [markdown]
# **Kết luận: Sau khi thử chọn lọc 26 feature (có score > 200) model có accuracy score không cao bằng**

# %% [markdown]
#  **------------------------------------------------------ End - KNN -------------------------------------------------------**

# %% [markdown]
#  **---------------------------------------------------- 2. DECISIONTREE CLASSIFIER  ----------------------------------------------------------**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(criterion='entropy') # nen dung Gini vi day la thuoc tinh lien tuc
tree_model = clf.fit(X_train, y_train)

# %%
# Kiểm tra độ chính xác
print("The Train prediction accuracy is: ", tree_model.score(X_train, y_train)*100,"%")
print("The Test prediction accuracy is: ", tree_model.score(X_test, y_test)*100,"%")
# Out:
# The Train prediction accuracy is:  99.70811441914769 %
# The Test prediction accuracy is:  70.74829931972789 %

# %% [markdown]
# **=> Overfitting**

# %% [markdown]
# **Try Feature Selection:** Thử chọn 26 fearture (có score > 200) để xem có thể giảm độ nhiễu, tăng score cho Model được hay không?

# %%
best_feature = featureScores[featureScores['Score'] > 200]['Specs'].values
best_feature
# Out:
# array(['basil', 'cardamom', 'cilantro', 'coconut', 'coriander', 'cumin',
#        'fenugreek', 'fish', 'lemongrass', 'lime', 'lime_juice', 'pepper',
#        'pork', 'roasted_sesame_seed', 'sake', 'scallion', 'seaweed',
#        'sesame_oil', 'soy_sauce', 'soybean', 'starch', 'tomato',
#        'turmeric', 'wasabi', 'wine', 'yogurt'], dtype=object)

# %%
inputs_best = data[best_feature]
inputs_best.head()
# Out:
#     basil  cardamom  cilantro  coconut  coriander  cumin  fenugreek  fish  \
# 65      0         0         0        1          1      1          1     1
# 66      0         1         0        0          0      0          0     0
# 67      0         1         0        0          0      0          0     0
# 68      0         0         0        1          0      0          1     0
# 69      0         1         0        0          0      1          0     0
#
#     lemongrass  lime  ...  seaweed  sesame_oil  soy_sauce  soybean  starch  \
# 65           0     0  ...        0           0          0        0       0
# 66           0     0  ...        0           0          0        0       0
# 67           0     0  ...        0           0          0        0       0
# 68           0     0  ...        0           0          0        0       0
# 69           0     0  ...        0           0          0        0       0
#
#     tomato  turmeric  wasabi  wine  yogurt
# 65       1         1       0     0       0
# 66       0         0       0     0       0
# 67       0         0       0     0       0
# 68       1         1       0     0       0
# 69       0         0       0     0       1
#
# [5 rows x 26 columns]

# %%
clf = DecisionTreeClassifier(criterion='entropy') # nen dung Gini vi day la thuoc tinh lien tuc
tree_model = clf.fit(X_train_best, y_train_best)

# %%
# Kiểm tra độ chính xác
print("The Train prediction accuracy is: ", tree_model.score(X_train_best, y_train_best)*100,"%")
print("The Test prediction accuracy is: ", tree_model.score(X_test_best, y_test_best)*100,"%")
# Out:
# The Train prediction accuracy is:  82.5452422650321 %
# The Test prediction accuracy is:  69.1156462585034 %

# %% [markdown]
# **=> Vẫn không giảm được overfitting**

# %% [markdown]
#  **------------------------------------------------------ End - Decision Tree -------------------------------------------------------**

# %% [markdown]
#  **---------------------------------------------------- 3. RANDOM FOREST  ----------------------------------------------------------**

# %% [markdown]
# **Chọn số lượng cây n_estimators phù hợp**

# %%
from sklearn.ensemble import RandomForestClassifier
list_n = []
list_acc = []
for n_estimators in [10, 30, 50, 70, 100, 120, 150, 170, 200, 250, 300]:        
    list_n.append(n_estimators)
    clf = RandomForestClassifier(n_estimators = n_estimators)
    forest_model = clf.fit(X_train, y_train)
    y_pred = forest_model.predict(X_test)
    acc = accuracy_score(y_test,y_pred)*100 
    list_acc.append(acc)
    print("Accuracy is ", accuracy_score(y_test,y_pred)*100,"% for n_estimators:",n_estimators)
# Out:
# Accuracy is  76.05442176870748 % for n_estimators: 10
# Accuracy is  80.27210884353741 % for n_estimators: 30
# Accuracy is  80.1360544217687 % for n_estimators: 50
# Accuracy is  79.59183673469387 % for n_estimators: 70
# Accuracy is  79.8639455782313 % for n_estimators: 100
# Accuracy is  80.95238095238095 % for n_estimators: 120
# Accuracy is  80.27210884353741 % for n_estimators: 150
# Accuracy is  81.63265306122449 % for n_estimators: 170
# Accuracy is  80.81632653061224 % for n_estimators: 200
# Accuracy is  80.27210884353741 % for n_estimators: 250
# Accuracy is  80.95238095238095 % for n_estimators: 300

# %%
import matplotlib.pyplot as plt
plt.plot(list_n, list_acc)
plt.xlabel('n_estimators')
plt.ylabel('Test Accuracy')
plt.show()

# %%
vi_tri = list_acc.index(max(list_acc))
n = list_n[vi_tri]
print("The optimal n_estimators is", n,"with", list_acc[vi_tri])
# Out:
# The optimal n_estimators is 170 with 81.63265306122449

# %%
clf = RandomForestClassifier(n_estimators = n)
forest_model = clf.fit(X_train, y_train)

# %%
y_pred = forest_model.predict(X_test)

# %%
# Kiểm tra độ chính xác
print("The Training prediction accuracy is: ",
      forest_model.score(X_train,y_train)*100,"%")
print("The Testing prediction accuracy is: ",
      forest_model.score(X_test,y_test)*100,"%")
# Out:
# The Training prediction accuracy is:  99.70811441914769 %
# The Testing prediction accuracy is:  81.08843537414965 %

# %% [markdown]
# **Đánh giá model => Dùng confuse matrix**

# %%
df = pd.DataFrame({'Actual': pd.DataFrame(y_test['cuisine'].to_list())[0].values, 
                   'Prediction': pd.DataFrame(y_pred)[0].values})  
df.head()
# Out:
#    Actual Prediction
# 0  korean     korean
# 1  korean     korean
# 2  korean     korean
# 3  korean     korean
# 4    thai       thai

# %%
from sklearn.metrics import confusion_matrix, classification_report
confusion_matrix(y_test, y_pred)
# Out:
# array([[103,   7,  10,  22,   3],
#        [  0, 171,   0,   3,   3],
#        [ 10,   7,  48,  21,   2],
#        [ 10,   3,   5, 210,   1],
#        [  7,  21,   0,   7,  61]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      chinese       0.79      0.71      0.75       145
#       indian       0.82      0.97      0.89       177
#     japanese       0.76      0.55      0.64        88
#       korean       0.80      0.92      0.85       229
#         thai       0.87      0.64      0.73        96
#
#    micro avg       0.81      0.81      0.81       735
#    macro avg       0.81      0.75      0.77       735
# weighted avg       0.81      0.81      0.80       735

# %% [markdown]
# **Nhận xét: Quan sát kết quả và đánh giá: Mô hình với n_estimators = 170 có độ chính xác cho Train là 99% Test là 81%, class dự đoán tương đối chính xác.**

# %% [markdown]
# **Try Feature Selection:** Thử chọn 26 fearture (có score > 200) để xem có thể giảm độ nhiễu, tăng score cho Model được hay không?

# %%
best_feature = featureScores[featureScores['Score'] > 200]['Specs'].values
best_feature
# Out:
# array(['basil', 'cardamom', 'cilantro', 'coconut', 'coriander', 'cumin',
#        'fenugreek', 'fish', 'lemongrass', 'lime', 'lime_juice', 'pepper',
#        'pork', 'roasted_sesame_seed', 'sake', 'scallion', 'seaweed',
#        'sesame_oil', 'soy_sauce', 'soybean', 'starch', 'tomato',
#        'turmeric', 'wasabi', 'wine', 'yogurt'], dtype=object)

# %%
inputs_best = data[best_feature]
inputs_best.head()
# Out:
#     basil  cardamom  cilantro  coconut  coriander  cumin  fenugreek  fish  \
# 65      0         0         0        1          1      1          1     1
# 66      0         1         0        0          0      0          0     0
# 67      0         1         0        0          0      0          0     0
# 68      0         0         0        1          0      0          1     0
# 69      0         1         0        0          0      1          0     0
#
#     lemongrass  lime  ...  seaweed  sesame_oil  soy_sauce  soybean  starch  \
# 65           0     0  ...        0           0          0        0       0
# 66           0     0  ...        0           0          0        0       0
# 67           0     0  ...        0           0          0        0       0
# 68           0     0  ...        0           0          0        0       0
# 69           0     0  ...        0           0          0        0       0
#
#     tomato  turmeric  wasabi  wine  yogurt
# 65       1         1       0     0       0
# 66       0         0       0     0       0
# 67       0         0       0     0       0
# 68       1         1       0     0       0
# 69       0         0       0     0       1
#
# [5 rows x 26 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
list_n = []
list_acc = []
for n_estimators in [10, 30, 50, 70, 100, 120, 150, 170, 200, 250, 300]:        
    list_n.append(n_estimators)
    clf = RandomForestClassifier(n_estimators = n_estimators)
    forest_model = clf.fit(X_train_best, y_train_best)
    y_pred_best = forest_model.predict(X_test_best)
    acc = accuracy_score(y_test_best,y_pred_best)*100 
    list_acc.append(acc)
    print("Accuracy is ", accuracy_score(y_test_best,y_pred_best)*100,"% for n_estimators:",n_estimators)
# Out:
# Accuracy is  71.56462585034014 % for n_estimators: 10
# Accuracy is  72.10884353741497 % for n_estimators: 30
# Accuracy is  71.70068027210884 % for n_estimators: 50
# Accuracy is  72.10884353741497 % for n_estimators: 70
# Accuracy is  71.29251700680273 % for n_estimators: 100
# Accuracy is  71.70068027210884 % for n_estimators: 120
# Accuracy is  71.97278911564626 % for n_estimators: 150
# Accuracy is  72.10884353741497 % for n_estimators: 170
# Accuracy is  71.70068027210884 % for n_estimators: 200
# Accuracy is  71.56462585034014 % for n_estimators: 250
# Accuracy is  71.29251700680273 % for n_estimators: 300

# %%
import matplotlib.pyplot as plt
plt.plot(list_n, list_acc)
plt.xlabel('n_estimators')
plt.ylabel('Test Accuracy')
plt.show()

# %%
vi_tri = list_acc.index(max(list_acc))
n = list_n[vi_tri]
print("The optimal n_estimators is", n,"with", list_acc[vi_tri])
# Out:
# The optimal n_estimators is 30 with 72.10884353741497

# %%
clf = RandomForestClassifier(n_estimators = n)
forest_model = clf.fit(X_train_best, y_train_best)

# %%
y_pred_best = forest_model.predict(X_test_best)

# %%
# Kiểm tra độ chính xác
print("The Training prediction accuracy is: ",
      forest_model.score(X_train_best,y_train_best)*100,"%")
print("The Testing prediction accuracy is: ",
      forest_model.score(X_test_best,y_test_best)*100,"%")
# Out:
# The Training prediction accuracy is:  82.5452422650321 %
# The Testing prediction accuracy is:  71.156462585034 %

# %% [markdown]
# **=> Select Feature làm giảm score**

# %% [markdown]
#  **------------------------------------------------------ End - Random Forest -------------------------------------------------------**

# %% [markdown]
# **>>>>>>>>>>>> KẾT LUẬN: CHỌN RANDOM FOREST LÀ MÔ HÌNH PHÙ HỢP NHẤT (giữ nguyên toàn bộ inputs) <<<<<<<<<<<<**

# %% [markdown]
# **5. Dựa trên kết quả, hãy cho biết nếu trong thành phần của món ăn có “cumin” và “fish” nhưng không có “yogurt” thì món ăn đó thường là món ăn của nước nào? **

# %%
clf = RandomForestClassifier(n_estimators = 170)
forest_model = clf.fit(X_train, y_train)

# %%
X_new1 = pd.DataFrame(columns=inputs.columns.to_list())
X_new1 = X_new1.append(pd.DataFrame({'cumin': [1], 'fish': [1], 'yogurt': [0]}))
X_new1 = X_new1.fillna(0)
# X_new1
y_pred_new1 = forest_model.predict(X_new1)

# %%
y_pred_new1
# Out:
# array(['indian'], dtype=object)

# %% [markdown]
# **6. Dựa trên kết quả, hãy cho biết nếu trong thành phần của món ăn có cumin nhưng không có “fish” và không có “soy_sauce” thì món ăn đó thường là món ăn của nước nào? **

# %%
X_new2 = pd.DataFrame(columns=inputs.columns.to_list())
X_new2 = X_new2.append(pd.DataFrame({'cumin': [1], 'fish': [0], 'soy_sauce': [0]}))
X_new2 = X_new2.fillna(0)
# X_new2
y_pred_new2 = forest_model.predict(X_new2)

# %%
y_pred_new2
# Out:
# array(['indian'], dtype=object)

# %% [markdown]
# **7. In nội dung confusion matrix sau đó trả lời các câu hỏi sau :**
#     a. Tỷ lệ % các công thức món ăn của Nhật Bản được dự đoán chính xác ?
#     b. Tỷ lệ % các công thức món ăn của Hàn Quốc bị gán sai nhãn thành Nhật Bản?
#     c. Nước nào có tỷ lệ % các công thức món ăn bị gán nhãn sai nhiều nhất ?

# %%
from sklearn.metrics import confusion_matrix, classification_report
confusion_matrix(y_test, y_pred, labels=["chinese", "indian", "japanese", "korean", "thai"])
# Out:
# array([[105,   6,   9,  22,   3],
#        [  1, 169,   0,   3,   4],
#        [ 11,   5,  49,  19,   4],
#        [ 12,   1,   7, 209,   0],
#        [  8,  17,   0,   7,  64]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      chinese       0.77      0.72      0.74       145
#       indian       0.85      0.95      0.90       177
#     japanese       0.75      0.56      0.64        88
#       korean       0.80      0.91      0.85       229
#         thai       0.85      0.67      0.75        96
#
#    micro avg       0.81      0.81      0.81       735
#    macro avg       0.81      0.76      0.78       735
# weighted avg       0.81      0.81      0.80       735

# %% [markdown]
# **Nhận xét:**
#     a. Các công thức món ăn của Nhật Bản được dự đoán chính xác khoảng 75% (49/65)
#     b. Các công thức món ăn của Hàn Quốc bị gán sai nhãn thành Nhật Bản khoảng 7% (19/260)
#     c. Nước có tỷ lệ % các công thức món ăn bị gán nhãn sai nhiều nhất là Nhật Bản (precision thấp nhất)
